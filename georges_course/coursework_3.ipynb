# %%
import numpy as np
import xarray as xr
import matplotlib.pylab as plt

# %%
t = np.arange('2022-01', '2023-01', dtype='datetime64[D]')

# %%
x = np.sin(np.arange(len(t)))

# %%
dataset = xr.Dataset({
"x":(x),
"t": (t),
})

# %%
dataset
# Out:
# <xarray.Dataset>
# Dimensions:  (x: 365, t: 365)
# Coordinates:
#   * x        (x) float64 0.0 0.8415 0.9093 0.1411 ... -0.657 -0.9894 -0.4121
#   * t        (t) datetime64[ns] 2022-01-01 2022-01-02 ... 2022-12-30 2022-12-31
# Data variables:
#     *empty*
